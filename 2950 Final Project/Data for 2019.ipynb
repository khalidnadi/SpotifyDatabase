# %%
import pandas
from collections import Counter
import re
import matplotlib.pyplot
import numpy

# %%
data = pandas.read_csv("data_2019.csv")
data.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.717   0.653    1    -5.634     1       0.0658       0.22900
# 1         0.752   0.488    6    -7.050     1       0.0705       0.29700
# 2         0.834   0.730    8    -3.714     1       0.2220       0.00513
# 3         0.760   0.479    2    -5.574     1       0.0466       0.55600
# 4         0.579   0.904    5    -2.729     1       0.0618       0.19300
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1010    0.412  106.966  audio_features
# 1          0.000009    0.0936    0.533  136.041  audio_features
# 2          0.000000    0.1240    0.446  155.008  audio_features
# 3          0.000000    0.0703    0.913   89.911  audio_features
# 4          0.000000    0.0640    0.681   82.014  audio_features
#
#                        id                                   uri  \
# 0  3e9HZxeyfWwjeyPAMmWSSQ  spotify:track:3e9HZxeyfWwjeyPAMmWSSQ
# ...

# %%
import pandas
from collections import Counter
import re
import matplotlib.pyplot
import numpy
from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs

# %%
playlist = pandas.read_csv('popular_music_2019.csv')
playlist.columns = playlist.columns.str.replace(' ', '_')
playlist.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a8d6b9654a85> in <module>()
# ----> 1 playlist = pandas.read_csv('popular_music_2019.csv')
#       2 playlist.columns = playlist.columns.str.replace(' ', '_')
#       3 playlist.head()
#
# NameError: name 'pandas' is not defined

# %%
tracks = playlist["Track_Name"]
artists = playlist["Artist_Name"]
albums = playlist["Album_Name"]

data["Track_Name"] = tracks
data["Artist_Name"] = artists
data["Album_Name"] = albums

data.head(100)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.717   0.653    1    -5.634     1       0.0658       0.22900
# 1          0.752   0.488    6    -7.050     1       0.0705       0.29700
# 2          0.834   0.730    8    -3.714     1       0.2220       0.00513
# 3          0.760   0.479    2    -5.574     1       0.0466       0.55600
# 4          0.579   0.904    5    -2.729     1       0.0618       0.19300
# 5          0.687   0.792    5    -2.749     1       0.0452       0.19100
# 6          0.896   0.671    1    -6.977     0       0.2890       0.10300
# 7          0.611   0.462    0    -7.054     1       0.0646       0.55800
# 8          0.861   0.603    8    -5.788     0       0.1760       0.05210
# 9          0.729   0.625    4    -5.266     1       0.0315       0.19400
# 10         0.800   0.578    4    -5.144     0       0.0485       0.00381
# 11         0.950   0.590    8    -6.508     0       0.2900       0.00534
# ...
